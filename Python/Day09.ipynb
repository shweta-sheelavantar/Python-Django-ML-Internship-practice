# %%
temp=[23,32,31,25,18,26,27,28,22]

h=max(temp)
    
print("highest temp:",h)

l=min(temp)
print("lowest temp:",l)

empty=[]
for t in temp:
    if t>22:
        empty.append(t)
    print("Days above 22 deg c",len(empty))
    today_temp=23
    temp.append(today_temp)
    print("update temp",temp)

# %%
# Tupale

it is orderd
immutable

allows duplicates

hetrogeneoues

indexes ==> element are accessed using index

# %%
#empty tuple
t=()
t2=tuple()
t=(5)
print(type(t))
t=(5,)
print(type(t))
# Out:
# <class 'int'>
# <class 'tuple'>

# %%
t=("a",2,45,75.0)
print(len(t))

print(t[0])
print(t[-1])
print(t[1:3])
# Out:
# 4
# a
# 75.0
# (2, 45)

# %%
t=(1,2,3,5,67,54,66,69,8)
#min
print(min(t))
print(max(t))
print(len(t))
print(sum(t))
print(sorted(t))

print("D_0:",sorted(t,reverse=True))
# Out:
# 1
# 69
# 9
# 275
# [1, 2, 3, 5, 8, 54, 66, 67, 69]
# D_0: [69, 67, 66, 54, 8, 5, 3, 2, 1]

# %%
t1=(12,23)
t2=(4,3)
print(t1+t2)
# Out:
# (12, 23, 4, 3)

# %%
# repetition
print(t1*4)
# Out:
# (12, 23, 12, 23, 12, 23, 12, 23)

# %%
#membership opertor 
print(2 in t1)
print(12 not in t1)
# Out:
# False
# False

# %%
#built in methods

t=(1,2,3,4,3,5,2,3,2)
print(t.count(2))
print(t.index(3))
# Out:
# 3
# 2

# %%
# packing

p=("KT",25,"Eng")

#unpacking
name, age, job=p
print(name)
print(age)
print(job)
# Out:
# KT
# 25
# Eng

# %%
dir(t)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %% [markdown]
# ### set

# %%
unordered(can't use on index position)

unindex
          
muteable
no dulicates
hetrogenous

# %%
#empty set

empty_set=set()

s={"a","b","c"}
print(s)
# Out:
# {'c', 'b', 'a'}

# %%
s[0]# it is unorder so it will get errror
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [48], in <cell line: 1>()
# ----> 1 s[0]
#
# TypeError: 'set' object is not subscriptable

# %%
#add an item
s.add("d")
print(s)
# Out:
# {'c', 'd', 'b', 'a'}

# %%
#add mutiple item
s.update(["e","f"])
print(s)
# Out:
# {'e', 'b', 'c', 'a', 'f'}

# %%
#remove
s.remove("d")
print(s)
# Out:
# {'c', 'b', 'a'}

# %%
#pop remove random item
s.pop()
print(s)
# Out:
# {'b', 'c', 'a', 'f'}

# %%
s={2,45,6,67,78}
print(min(s))
print(max(s))
print(sum(s))
print(len(s))
# Out:
# 2
# 78
# 198
# 5

# %%
s.clear() # clear

# %%
# set operation
a={1,2,3,4}
b={5,6,7,2,3}

print(a|b) #union
print(a&b) #common value =intersection
print(a-b) #differnce
print(a^b) #symmetric difference
print("a" in a)

print(4 not in b)
print(4 in a)
# Out:
# {1, 2, 3, 4, 5, 6, 7}
# {2, 3}
# {1, 4}
# {1, 4, 5, 6, 7}
# False
# True
# True

# %%
# set are removing dulicates

l=[1,2,3,3,4,5,5,6]
u=set(l)
print(u)
# Out:
# {1, 2, 3, 4, 5, 6}

# %% [markdown]
# # dict

# %%
A distionary is a collection of key value pairs

unordered 

mutable

key must be unique-- duplicates are not allowed
key must be immutable type

# %%
#empty dict
d={}

# %%
student={
    "name":"kt",
    "age":22,
    "course":"cs"
}
print(student["name"])
print(student.get("age"))
print(student)
# Out:
# kt
# 22
# {'name': 'kt', 'age': 22, 'course': 'cs'}

# %%
print(student.get("grade"))
# Out:
# None

# %%
print(student.get("grade"))
print(student.get("grade","not Found"))
# Out:
# None
# not Found

# %%
#update
student["age"]=23
print(student)
# Out:
# {'name': 'kt', 'age': 23, 'course': 'cs'}

# %%
#add a new key & value
student["grade"]="A"
print(student)
# Out:
# {'name': 'kt', 'age': 23, 'course': 'cs', 'grade': 'A'}

# %%
# remove by ke
student.pop("course")
print(student)
# Out:
# {'name': 'kt', 'age': 23, 'grade': 'A'}

# %%
#remove last inserted item
student.popitem()
print(student)
# Out:
# {'name': 'kt', 'age': 23}

# %%
student.clear()

# %%
student={
    "name":"Kt",
    "age":22,
    "course":"cs"
    
}
for key in student:
    print(key,"==>",student[key])
# Out:
# name ==> Kt
# age ==> 22
# course ==> cs

# %%
print(student.keys())
# Out:
# dict_keys(['name', 'age', 'course'])

# %%
print(student.values())
# Out:
# dict_values(['Kt', 22, 'cs'])

# %%
print(student.items())
# Out:
# dict_items([('name', 'Kt'), ('age', 22), ('course', 'cs')])

# %%
#merge dictionary
s2={"course":"cs","grade":"A"}
student.update(s2)
print(student)
# Out:
# {'name': 'Kt', 'age': 22, 'course': 'cs', 'grade': 'A'}

# %%
marks={"m":99,"p":98,"c":96} #avg
print(sum(marks))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [104], in <cell line: 2>()
#       1 marks={"m":99,"p":98,"c":96}
# ----> 2 print(sum(marks))
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
### simple login page

username=["user1","user2","user3","user4","user5"]
password=["pass1","pass2","pass3","pass4","pass5"]

usr=input("Enter the username:")

if usr in username:
    print("valid username!")
    i=username.index(usr)
    print(i)
    pwd=input("Enter the password:")
    if pwd==password[i]:
        print("valid password! Alow login")
    else:
        print("Invalid password")
        
else:
    print("Invalid username")
# Out:
# Enter the username:user1
# valid username!
# 0
# Enter the password:pass1
# valid password! Alow login

# %%
users={
    "user1": "pass1",
    "user2": "pass2",
    "user3":"pass3",
    "user4": "pass4",
    "user5":"pass5"
}

usr=input("Enter the username:")

if usr in users:
    pwd=input("Enter the password:")
    if pwd==users[usr]:
        print("valid password! allow to login")
    else:
        print("Invalid password")
else:
    print("Invalid user name")
# Out:
# Enter the username:user4
# Enter the password:pass4
# valid password! allow to login
