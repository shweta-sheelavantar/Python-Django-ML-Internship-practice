# %% [markdown]
# #Basics of python

# %% [markdown]
# # Basics of python

# %% [markdown]
# ## Basics of python

# %% [markdown]
# ### Basics of python

# %% [markdown]
# #### Basics of python

# %%
a=5
print(a)
print(type(a))
print(id(a))
# Out:
# 5
# <class 'int'>
# 2325775542704

# %%
s="Karunadu Technologies"
print(s)
print(type(s))
# Out:
# Karunadu Technologies
# <class 'str'>

# %%
s[1]
# Out:
# 'a'

# %%
s[-1]
# Out:
# 's'

# %%
s[0:8]
# Out:
# 'Karunadu'

# %%
s[0:8:2]
# Out:
# 'Krnd'

# %%
s[0:8:3]
# Out:
# 'Kud'

# %%
s[0:4:1]
# Out:
# 'Karu'

# %%
s[0:5:3]
# Out:
# 'Ku'

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
# ...

# %%
s.count("K")
# Out:
# 1

# %%
s.index("K")
# Out:
# 0

# %% [markdown]
# s.index("a")

# %%
s.index("s")
# Out:
# 20

# %%
s
# Out:
# 'Karunadu Technologies'

# %%
s.upper()
# Out:
# 'KARUNADU TECHNOLOGIES'

# %%
s.lower()
# Out:
# 'karunadu technologies'

# %%
s.title()
# Out:
# 'Karunadu Technologies'

# %%
s.split()
# Out:
# ['Karunadu', 'Technologies']

# %%
s1="hello"
s2="MS"
print(s1.join(s2))
# Out:
# MhelloS

# %% [markdown]
# # Bool Data type

# %%
bool(1)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
print(True+True+bool(-1))
# Out:
# 3

# %%
print(False+bool(0))
# Out:
# 0

# %% [markdown]
# # Complex number

# %%
c=2+3j
print(c)
print(type(c))
# Out:
# (2+3j)
# <class 'complex'>

# %%
dir(complex)
# Out:
# ['__abs__',
#  '__add__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__le__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmod__',
#  '__rmul__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  'conjugate',
#  'imag',
#  'real']

# %%
c.real+c.imag
# Out:
# 5.0

# %%
c.imag
# Out:
# 3.0

# %%
f_name="Karunadu"
l_name="Tech"
f_name=f_name+"  ,  "+l_name
print(f_name)
# Out:
# Karunadu  ,  Tech

# %%
s*3
# Out:
# 'Karunadu TechnologiesKarunadu TechnologiesKarunadu Technologies'

# %%
"Karunadu"+str(27)
# Out:
# 'Karunadu27'

# %% [markdown]
# # Type Casating

# %%
a=2
print(a)
print(type(a))
# Out:
# 2
# <class 'int'>

# %%
b=float(a)
print(b)
print(type(b))
# Out:
# 2.0
# <class 'float'>

# %%
c=str(a)
print(c)
print(type(c))
# Out:
# 2
# <class 'str'>

# %%
s="10"
a=int(s)

# %%
s.isnumeric()
# Out:
# True

# %%
s="ten"
a=int(s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [56], in <cell line: 2>()
#       1 s="ten"
# ----> 2 a=int(s)
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %%
s.isnumeric()
# Out:
# False

# %%
int=2

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  '__peg_parser__',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
f_name=input("Enter the first name:")
l_name=input("Enter the last name:")
f_name=f_name+"  ,  "+l_name
print("Full name:",f_name)
# Out:
# Enter the first name:shweta
# Enter the last name:SM
# Full name: shweta  ,  SM

# %%
f_name="shweta"
l_name="sm"
fa_number=7
fa_number=fa_number+2
email_name=f_name+l_name+str(fa_number)
email=email_name+"@gmail.com"
print(email)
# Out:
# shwetasm9@gmail.com

# %%
first_name=input("Enter the first name:")
last_name=input("Enter the last name:")
fav_num=int(input("Enter the fav number:"))
fav_num=fav_num+5
Email_Id=first_name+last_name+str(fav_num)+"@gmail.com"
print(Email_Id)
# Out:
# Enter the first name:shweta
# Enter the last name:sm
# Enter the fav number:7
# shwetasm12@gmail.com
